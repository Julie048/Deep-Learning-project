# %% [markdown]
# For my project, I will try to combine a CNN and an RNN model like in the paper described in my projet proposal, as the model described was very accurate.
# Combining these two types of neural network will enable me to exploit their respective strengths: CNNs are effective at extracting local patterns, while RNNs capture sequential order and contextual information. I will use the architecture from the paper, with some simplifications, to make the implementation easier and better suited to my level. A diagram of the architecture is in 1.
#
# First the dataset is cleaned and tokenized. Then padding is added (since the CNN can only process inputs of the same lenght) and an embedding layer is added to focus on politically meaningful words. The data are then run through four neural networks in parallel: three CNNs with different filter sizes (2, 3 and 4) to detect bigrams, trigrams and quadrigrams, and an LSTM to process word order. The outputs of CNNs and LSTM layers are then run through a max pooling function to focus on the most important features detected. The outputs of CNNs and LSTM layers are then concatenated into a vector, which passes through two fully connected layers for feature refinement and a dropout layer to prevent overfitting. Finally, a softmax layer computes the final probabilities for each political party.

# %% [markdown]
# ## Data loading, spliting, and tokenazing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#for google collab
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_parquet('/content/drive/MyDrive/congress_tweets_dataset_cleaned.parquet')
# Out:
# Mounted at /content/drive

# %%
#for vs code
df = pd.read_parquet('congress_tweets_dataset_cleaned.parquet')

# %%
#Load and split the Data

# We use 75% for training, 10% for validation and 15% for testing and take the most recents tweets for testing

#Ensure the time column is in datetime format
df['time'] = pd.to_datetime(df['time'], utc=True)
df = df.sort_values('time').reset_index(drop=True)

train_ratio = 0.75
validation_ratio = 0.85

# Split each party's data chronologically
# This ensures that for BOTH 'D' and 'R', the last 25% are used for testing (so we keep the same proportion of republicain and democrat tweets in both sets)

test_list = []
temp_train_val_list = []  #I don't want the validation set to have more recent tweets than the training set

for label in ['D', 'R']:
    party_df = df[df['label'] == label]

    # Calculate the split point (index)
    split_idx = int(len(party_df) * validation_ratio)

    # Split: first 85% to train+validation, last 15% to test
    temp_train_val_list.append(party_df.iloc[:split_idx])
    test_list.append(party_df.iloc[split_idx:])

# Combine the splits back into final DataFrames
df_train_val = pd.concat(temp_train_val_list)
df_test = pd.concat(test_list)

# Shuffle the training and test/val data (because I want the most recent tweets for testing but I want validation and training to be randomly sampled from the rest of the data)
df_train_val = df_train_val.sample(frac=1, random_state=42).reset_index(drop=True)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True)

#creating the validation and train set and making sure to keep the same R/D ratio in both sets
train_list = []
validation_list = []

for label in ['D', 'R']:
    party_df = df_train_val[df_train_val['label'] == label]

    # Calculate the split point (index)
    split_idx = int(len(party_df) * (train_ratio/validation_ratio))

    # Split: 75/85% of train and 10/85% of validation
    train_list.append(party_df.iloc[:split_idx])
    validation_list.append(party_df.iloc[split_idx:])

# Combine the splits back into final DataFrames
df_train = pd.concat(train_list)
df_validation = pd.concat(validation_list)

# We split the features and the labels
X_train, y_train = df_train['text'], df_train['label']
X_val, y_val = df_validation['text'], df_validation['label']
X_test, y_test = df_test['text'], df_test['label']

# Verification
print(f"Training set size: {len(X_train)} (Ending at {df_train['time'].max()})")
print(f"Validation set size: {len(X_val)} (Ending at {df_validation['time'].max()})")
print(f"Test set size: {len(X_test)} (Starting from {df_test['time'].min()})")
print(f"\nLabel distribution in Test set:\n{y_test.value_counts(normalize=True)}")
# Out:
# Training set size: 3264205 (Ending at 2022-07-28 05:52:12+00:00)
# Validation set size: 435228 (Ending at 2022-07-28 04:58:45+00:00)
# Test set size: 652842 (Starting from 2022-05-24 15:20:42+00:00)
#
# Label distribution in Test set:
# label
# D    0.589824
# R    0.410176
# Name: proportion, dtype: float64

# %% [markdown]
# Preparation of the data (tokenization and creation of dataloaders)

# %%
import torch
from collections import Counter
import numpy as np
import re

# %%
label_map = {'R': 0, 'D': 1}
y_train_num = y_train.map(label_map).values
y_val_num = y_val.map(label_map).values
y_test_num = y_test.map(label_map).values

# Tokenization
#We keep remove capital letters and urls

def tokenize(text):
    text = text.lower()
    return str(text).split()

#construction of a vocabulary dictionary mapping each word to a unique index.
word_counts = Counter()
for text in X_train:
    word_counts.update(tokenize(text))

#to reduce noise, we ignore words that appear less than 40 times in the training set and we add special tokens for padding and unknown words.
min_freq = 40
vocab = {'<PAD>': 0, '<UNK>': 1}

for word, count in word_counts.items():
    if count >= min_freq:
        vocab[word] = len(vocab)

print(f"Vocabulary size : {len(vocab)} words.")
# Out:
# Vocabulary size : 71642 words.

# %%
lengths = [len(tokenize(tweet)) for tweet in X_val]

df_lengths = pd.Series(lengths)

p80 = np.percentile(lengths, 80)
p90 = np.percentile(lengths, 90)
print(f"80th percentile of tweet lengths: {p80} words")
print(f"90th percentile of tweet lengths: {p90} words")

plt.figure(figsize=(10, 6))
plt.hist(lengths, bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of tweets lengths in the validation set')
plt.xlabel('Number of words')
plt.ylabel('Number of tweets')
plt.show()
# Out:
# 80th percentile of tweet lengths: 45.0 words
# 90th percentile of tweet lengths: 51.0 words

# %%
# Padding and text encoding

MAX_LEN = 50 #fixed lenght for the tweets, determined using the distribution of tweet lengths in the validation set, that allows to keep most of the tweets without too much noise and reduce the computational cost of the model

def encode_text(text):
    tokens = tokenize(text)
    #we replace each word by its index or by the index of <UNK> if it is unknown
    encoded = [vocab.get(word, vocab['<UNK>']) for word in tokens]

    #if the encoded tweet is shorter than MAX_LEN, we pad it with the index <PAD> until it reaches the correct lenght, otherwise we truncate it to MAX_LEN
    if len(encoded) < MAX_LEN:
        encoded += [vocab['<PAD>']] * (MAX_LEN - len(encoded))
    else:
        encoded = encoded[:MAX_LEN]

    return encoded

# %%
#the training dataset (after tokenization) is too big to be directly converted in a tensor so we have to use a class
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader, TensorDataset

class TweetDataset(Dataset):
    """because encoding all the tweet at once was too big for the memory, now that I reduced max_len at 50 so my code can run faster, I don't need the classe anymore"""
    def __init__(self, texts, labels):
        self.texts = texts.values
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]

        #we only encode the text of the tweet that we want to use, so we don't have to encode the whole dataset at once and we can use it with a DataLoader that will create batches for us
        encoded = encode_text(text)

        return torch.tensor(encoded, dtype=torch.long), torch.tensor(label, dtype=torch.long)
"""
train_dataset = TweetDataset(X_train, y_train_num)
val_dataset = TweetDataset(X_val, y_val_num)
test_dataset = TweetDataset(X_test, y_test_num)"""


X_train_tensor = torch.tensor([encode_text(text) for text in X_train], dtype=torch.long)
X_val_tensor = torch.tensor([encode_text(text) for text in X_val], dtype=torch.long)
X_test_tensor = torch.tensor([encode_text(text) for text in X_test], dtype=torch.long)

y_train_tensor = torch.tensor(y_train_num, dtype=torch.long)
y_val_tensor = torch.tensor(y_val_num, dtype=torch.long)
y_test_tensor = torch.tensor(y_test_num, dtype=torch.long)


train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

#I use smaller dataset to run the code faster while adjusting the hyperparameters, in the final version I will use the whole dataset
#with this purpose in mind, the vocabulary is built on the whole training set

"""for the tunning of the hyperparameters :
train_size = int(0.2 * len(X_train_tensor)) #20% of the training set
val_size = int(0.2 * len(X_val_tensor)) #20% of the validation set"""

#for the training (because the training with the full dataset was too long and the collab session disconected before the end)
train_size = int(0.7 * len(X_train_tensor)) #20% of the training set
val_size = int(0.7 * len(X_val_tensor)) #20% of the validation set

idx_train, _ = train_test_split(range(len(train_dataset)), train_size=train_size, stratify=y_train_num, random_state=42)
small_train_dataset = torch.utils.data.Subset(train_dataset, idx_train)

idx_val, _ = train_test_split(range(len(val_dataset)), train_size=val_size, stratify=y_val_num, random_state=42)
small_val_dataset = torch.utils.data.Subset(val_dataset, idx_val)

print(f"Small training set size: {len(small_train_dataset)}")
print(f"Small validation set size: {len(small_val_dataset)}")
# Out:
# Small training set size: 2284943
# Small validation set size: 304659

# %% [markdown]
# ## Model Building

# %%
import torch.nn as nn
import torch.nn.functional as F

class PoliticalClassifier(nn.Module):
    """Main model, largelly inspired by the paper described in the proposal"""
    def __init__(self, name, vocab_size =len(vocab), embedding_dim=80, hidden_dim=80 , dropout_prob=0.5):
        super(PoliticalClassifier, self).__init__()
        self.name = name
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=0) #to avoid empedding the padding filler

        #CNN Branches
        self.conv2 = nn.Conv1d(embedding_dim, 50, kernel_size=2)
        self.conv3 = nn.Conv1d(embedding_dim, 50, kernel_size=3)
        self.conv4 = nn.Conv1d(embedding_dim, 50, kernel_size=4)

        #LSTM
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)

        # global max pooling 1d like in the article
        self.pool = nn.AdaptiveMaxPool1d(1)

        # Fully connected layers for classification
        combined_dim = 150 + hidden_dim
        self.fc1 = nn.Linear(combined_dim, 64)
        self.fc2 = nn.Linear(64, 32)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc_out = nn.Linear(32, 2)

    def forward(self, text):
        embedded = self.embedding(text) # [batch, seq_len, emb_dim]

        # LSTM + Pooling
        lstm_out, _ = self.lstm(embedded)
        # On permute pour le pooling: [batch, hidden_dim, seq_len]
        lstm_feature = self.pool(lstm_out.permute(0, 2, 1)).squeeze(2)

        #  CNN + Pooling
        embedded_cnn = embedded.permute(0, 2, 1)
        x2 = self.pool(F.relu(self.conv2(embedded_cnn))).squeeze(2)
        x3 = self.pool(F.relu(self.conv3(embedded_cnn))).squeeze(2)
        x4 = self.pool(F.relu(self.conv4(embedded_cnn))).squeeze(2)

        # Concatenation
        combined = torch.cat((x2, x3, x4, lstm_feature), dim=1)

        # Dense Layers
        x = self.dropout(combined)
        x = F.relu(self.fc1(x))
        #x = self.dropout(x) #dropout here for model 1 and 2
        x = F.relu(self.fc2(x))

        # Output
        logits = self.fc_out(x)
        return logits

# %%
def get_model_name(name, batch_size, learning_rate, hidden_dim, embedding_dim, dropout_prob, epoch):
    path = "model_{0}_bs{1}_lr{2}_hidden{3}_embedding{4}_dropout{5}_epoch{6}".format(name, batch_size, learning_rate, hidden_dim, embedding_dim, dropout_prob, epoch)
    return path


def get_accuracy(model, train=False,small=False):
    model.eval() #in order not to have dropout
    if small :
        if train:
            data = small_train_dataset
        else:
            data = small_val_dataset
    else :
        if train:
            data = train_dataset
        else:
            data = val_dataset

    correct = 0
    total = 0
    with torch.no_grad():
        for text, labels in torch.utils.data.DataLoader(data, batch_size=128):
            #############################################
            # To Enable GPU Usage
            if torch.cuda.is_available():
                text = text.cuda()
                labels = labels.cuda()
            #############################################
            output = model(text)
            #select index with maximum prediction score
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(labels.view_as(pred)).sum().item()
            total += text.shape[0]
    return correct / total

# %%
def train(model, data, batch_size=128, learning_rate=0.001, hidden_dim=80, embedding_dim=80, dropout_prob=0.5, num_epochs=10,print_stat=True,small=False):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size,shuffle=True)

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-5)

    iters, losses, train_acc, val_acc = [], [], [], []

    # training
    n = 0 # the number of iterations
    for epoch in range(num_epochs):
        model.train() #in order to have dropout during training

        for text, labels in iter(train_loader):

            #To Enable GPU Usage
            text, labels = text.to(device), labels.to(device)

            out = model(text)             # forward pass
            loss = criterion(out, labels) # compute the total loss
            loss.backward()               # backward pass (compute parameter updates)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0) #to avoid exploding gradients, we clip the gradients to a maximum norm of 1.0
            optimizer.step()              # make the updates for each parameter
            optimizer.zero_grad()         # a clean up step for PyTorch

          # save the current training information
            iters.append(n)
            losses.append(float(loss.item()))             # compute *average* loss
            n += 1

        train_acc.append(get_accuracy(model, train=True, small=small))  # compute training accuracy at the end of the epoch
        val_acc.append(get_accuracy(model, train=False, small=small))  # compute validation accuracy

        if print_stat :
          print ("Epoch %d Finished. " % epoch )
          print(str(val_acc[-1]))

        # Save the current model (checkpoint) to a file
        model_path = get_model_name(model.name, batch_size, learning_rate, hidden_dim, embedding_dim, dropout_prob, epoch)
        #torch.save(model.state_dict(), model_path)

        path_on_drive = f"/content/drive/MyDrive/{model_path}"
        torch.save(model.state_dict(), path_on_drive)

    if print_stat:
      # plotting
      plt.title("Training Curve")
      plt.plot(iters, losses, label="Train")
      plt.xlabel("Iterations")
      plt.ylabel("Loss")
      plt.show()

      plt.title("Training Curve")
      plt.plot(range(num_epochs), train_acc, label="Training")
      plt.plot(range(num_epochs), val_acc, label="Validation")
      plt.xlabel("Iterations")
      plt.ylabel("Validation Accuracy")
      plt.legend(loc='best')
      plt.show()

      print("Final Training Accuracy: {}".format(train_acc[-1]))
      print("Final Validation Accuracy: {}".format(val_acc[-1]))

    print(f"Final Validation Accuracy {model.name}: {val_acc[-1]}")

# %% [markdown]
# ## Sanity Checking

# %%
#We check that the model is able to memorize the data on a small dataset

from torch.utils.data import Subset
debug_data = Subset(train_dataset, list(range(42)))
model = PoliticalClassifier("small_model")
train(model, debug_data, print_stat = False)
# Out:
# Epoch 0 Finished.
# Epoch 1 Finished.
# Epoch 2 Finished.
# Epoch 3 Finished.
# Epoch 4 Finished.
# Epoch 5 Finished.
# Epoch 6 Finished.
# Epoch 7 Finished.
# Epoch 8 Finished.
# Epoch 9 Finished.
# Final Validation Accuracy small_model: 0.5898241841058021

# %%
#obtain accuracy on 42 samples
correct = 0
total = 0
for txt, labels in torch.utils.data.DataLoader(debug_data, batch_size=42):
    if torch.cuda.is_available():
        txt = txt.cuda()
        labels = labels.cuda()
    output = model(txt)
    #select index with maximum prediction score
    pred = output.max(1, keepdim=True)[1]
    correct += pred.eq(labels.view_as(pred)).sum().item()
    total += txt.shape[0]
print('Accuracy on batch of 42: ', correct / total)
# Out:
# Accuracy on batch of 42:  1.0

# %% [markdown]
# yay !

# %% [markdown]
# ## Hyperparameters tunning

# %%
model5 = PoliticalClassifier("model5",)
#best model with punctuation and capital letters,
train(model5, small_train_dataset, batch_size=128, num_epochs=40,learning_rate=0.00002,small=True)
# Out:
# Epoch 0 Finished.
# Epoch 1 Finished.
# Epoch 2 Finished.
# Epoch 3 Finished.
# Epoch 4 Finished.
# Epoch 5 Finished.
# Epoch 6 Finished.
# Epoch 7 Finished.
# Epoch 8 Finished.
# Epoch 9 Finished.
# Epoch 10 Finished.
# Epoch 11 Finished.
# Epoch 12 Finished.
# Epoch 13 Finished.
# Epoch 14 Finished.
# Epoch 15 Finished.
# Epoch 16 Finished.
# Epoch 17 Finished.
# Epoch 18 Finished.
# Epoch 19 Finished.
# Epoch 20 Finished.
# Epoch 21 Finished.
# Epoch 22 Finished.
# Epoch 23 Finished.
# Epoch 24 Finished.
# Epoch 25 Finished.
# Epoch 26 Finished.
# Epoch 27 Finished.
# Epoch 28 Finished.
# Epoch 29 Finished.
# Epoch 30 Finished.
# Epoch 31 Finished.
# Epoch 32 Finished.
# Epoch 33 Finished.
# Epoch 34 Finished.
# Epoch 35 Finished.
# Epoch 36 Finished.
# Epoch 37 Finished.
# Epoch 38 Finished.
# Epoch 39 Finished.
# Final Training Accuracy: 0.8778308960374731
# Final Validation Accuracy: 0.8466310529036705
# Final Validation Accuracy model5: 0.8466310529036705

# %%
#model(self, name, vocab_size =len(vocab), embedding_dim=80, hidden_dim=80 , dropout_prob=0.5
#train(model, data, batch_size=128, learning_rate=0.001, hidden_dim=80, embedding_dim=80, dropout_prob=0.5, num_epochs=10,print_stat=True,small=False)

for embedding_dim in [50,100]:
    model = PoliticalClassifier(f"model_embedding_{embedding_dim}", embedding_dim=embedding_dim)
    train(model, small_train_dataset, batch_size=128, embedding_dim=embedding_dim, num_epochs=30,learning_rate=0.00002,small=True, print_stat=False)

for hidden_dim in [50,100]:
    model = PoliticalClassifier(f"model_hidden_{hidden_dim}", hidden_dim=hidden_dim)
    train(model, small_train_dataset, batch_size=128, hidden_dim=hidden_dim, num_epochs=30,learning_rate=0.00002,small=True, print_stat=False)
# Out:
# Epoch 0 Finished.
# Epoch 1 Finished.
# Epoch 2 Finished.
# Epoch 3 Finished.
# Epoch 4 Finished.
# Epoch 5 Finished.
# Epoch 6 Finished.
# Epoch 7 Finished.
# Epoch 8 Finished.
# Epoch 9 Finished.
# Epoch 10 Finished.
# Epoch 11 Finished.
# Epoch 12 Finished.
# Epoch 13 Finished.
# Epoch 14 Finished.
# Epoch 15 Finished.
# Epoch 16 Finished.
# Epoch 17 Finished.
# Epoch 18 Finished.
# Epoch 19 Finished.
# Epoch 20 Finished.
# Epoch 21 Finished.
# Epoch 22 Finished.
# Epoch 23 Finished.
# Epoch 24 Finished.
# Epoch 25 Finished.
# Epoch 26 Finished.
# Epoch 27 Finished.
# Epoch 28 Finished.
# Epoch 29 Finished.
# Final Validation Accuracy model_embedding_50: 0.8254695846975703
# Epoch 0 Finished.
# Epoch 1 Finished.
# Epoch 2 Finished.
# Epoch 3 Finished.
# Epoch 4 Finished.
# Epoch 5 Finished.
# Epoch 6 Finished.
# Epoch 7 Finished.
# Epoch 8 Finished.
# Epoch 9 Finished.
# Epoch 10 Finished.
# Epoch 11 Finished.
# Epoch 12 Finished.
# Epoch 13 Finished.
# Epoch 14 Finished.
# Epoch 15 Finished.
# Epoch 16 Finished.
# Epoch 17 Finished.
# Epoch 18 Finished.
# Epoch 19 Finished.
# Epoch 20 Finished.
# Epoch 21 Finished.
# Epoch 22 Finished.
# Epoch 23 Finished.
# Epoch 24 Finished.
# Epoch 25 Finished.
# Epoch 26 Finished.
# Epoch 27 Finished.
# Epoch 28 Finished.
# Epoch 29 Finished.
# Final Validation Accuracy model_embedding_100: 0.837670170601413
# Epoch 0 Finished.
# Epoch 1 Finished.
# Epoch 2 Finished.
# Epoch 3 Finished.
# Epoch 4 Finished.
# Epoch 5 Finished.
# Epoch 6 Finished.
# Epoch 7 Finished.
# Epoch 8 Finished.
# Epoch 9 Finished.
# Epoch 10 Finished.
# Epoch 11 Finished.
# Epoch 12 Finished.
# Epoch 13 Finished.
# Epoch 14 Finished.
# Epoch 15 Finished.
# Epoch 16 Finished.
# Epoch 17 Finished.
# Epoch 18 Finished.
# Epoch 19 Finished.
# Epoch 20 Finished.
# Epoch 21 Finished.
# Epoch 22 Finished.
# Epoch 23 Finished.
# Epoch 24 Finished.
# Epoch 25 Finished.
# Epoch 26 Finished.
# Epoch 27 Finished.
# Epoch 28 Finished.
# Epoch 29 Finished.
# Final Validation Accuracy model_hidden_50: 0.8367051525073238
# Epoch 0 Finished.
# Epoch 1 Finished.
# Epoch 2 Finished.
# Epoch 3 Finished.
# Epoch 4 Finished.
# Epoch 5 Finished.
# Epoch 6 Finished.
# Epoch 7 Finished.
# Epoch 8 Finished.
# Epoch 9 Finished.
# Epoch 10 Finished.
# Epoch 11 Finished.
# Epoch 12 Finished.
# Epoch 13 Finished.
# Epoch 14 Finished.
# Epoch 15 Finished.
# Epoch 16 Finished.
# Epoch 17 Finished.
# Epoch 18 Finished.
# Epoch 19 Finished.
# Epoch 20 Finished.
# Epoch 21 Finished.
# Epoch 22 Finished.
# Epoch 23 Finished.
# Epoch 24 Finished.
# Epoch 25 Finished.
# Epoch 26 Finished.
# Epoch 27 Finished.
# Epoch 28 Finished.
# Epoch 29 Finished.
# Final Validation Accuracy model_hidden_100: 0.8348670228042966
# Epoch 0 Finished.
# Epoch 1 Finished.

# %%
for dropout_prob in [0.3,0.7]:
    model = PoliticalClassifier(f"model_dropout_{dropout_prob}", dropout_prob=dropout_prob)
    train(model, small_train_dataset, dropout_prob=dropout_prob, batch_size=128, num_epochs=30,learning_rate=0.00002,small=True, print_stat=False)
# Out:
# Final Validation Accuracy model_dropout_0.3: 0.8324889425010052
# Final Validation Accuracy model_dropout_0.7: 0.8293411453845712

# %%
model = PoliticalClassifier(f"model_embedding_100_hidden_50", embedding_dim=100, hidden_dim=50)
train(model, small_train_dataset, batch_size=128, embedding_dim=100, num_epochs=40,hidden_dim=50, learning_rate=0.00002,small=True, print_stat=True)
# Out:
# Epoch 0 Finished.
# Epoch 1 Finished.
# Epoch 2 Finished.
# Epoch 3 Finished.
# Epoch 4 Finished.
# Epoch 5 Finished.
# Epoch 6 Finished.
# Epoch 7 Finished.
# Epoch 8 Finished.
# Epoch 9 Finished.
# Epoch 10 Finished.
# Epoch 11 Finished.
# Epoch 12 Finished.
# Epoch 13 Finished.
# Epoch 14 Finished.
# Epoch 15 Finished.
# Epoch 16 Finished.
# Epoch 17 Finished.
# Epoch 18 Finished.
# Epoch 19 Finished.
# Epoch 20 Finished.
# Epoch 21 Finished.
# Epoch 22 Finished.
# Epoch 23 Finished.
# Epoch 24 Finished.
# Epoch 25 Finished.
# Epoch 26 Finished.
# Epoch 27 Finished.
# Epoch 28 Finished.
# Epoch 29 Finished.
# Epoch 30 Finished.
# Epoch 31 Finished.
# Epoch 32 Finished.
# Epoch 33 Finished.
# Epoch 34 Finished.
# Epoch 35 Finished.
# Epoch 36 Finished.
# Epoch 37 Finished.
# Epoch 38 Finished.
# Epoch 39 Finished.
# Final Training Accuracy: 0.8793948296752195
# Final Validation Accuracy: 0.8481475099086679
# Final Validation Accuracy model_embedding_100_hidden_50: 0.8481475099086679

# %%
model = PoliticalClassifier(f"model_embedding_100_hidden_50_lr00004", embedding_dim=100, hidden_dim=50)
train(model, small_train_dataset, batch_size=128, embedding_dim=100, num_epochs=40,hidden_dim=50, learning_rate=0.00004,small=True, print_stat=True)
# Out:
# Epoch 0 Finished.
# Epoch 1 Finished.
# Epoch 2 Finished.
# Epoch 3 Finished.
# Epoch 4 Finished.
# Epoch 5 Finished.
# Epoch 6 Finished.
# Epoch 7 Finished.
# Epoch 8 Finished.
# Epoch 9 Finished.
# Epoch 10 Finished.
# Epoch 11 Finished.
# Epoch 12 Finished.
# Epoch 13 Finished.
# Epoch 14 Finished.
# Epoch 15 Finished.
# Epoch 16 Finished.
# Epoch 17 Finished.
# Epoch 18 Finished.
# Epoch 19 Finished.
# Epoch 20 Finished.
# Epoch 21 Finished.
# Epoch 22 Finished.
# Epoch 23 Finished.
# Epoch 24 Finished.
# Epoch 25 Finished.
# Epoch 26 Finished.
# Epoch 27 Finished.
# Epoch 28 Finished.
# Epoch 29 Finished.
# Epoch 30 Finished.
# Epoch 31 Finished.
# Epoch 32 Finished.
# Epoch 33 Finished.
# Epoch 34 Finished.
# Epoch 35 Finished.
# Epoch 36 Finished.
# Epoch 37 Finished.
# Epoch 38 Finished.
# Epoch 39 Finished.
# Final Training Accuracy: 0.8972889264001495
# Final Validation Accuracy: 0.8560629559423287
# Final Validation Accuracy model_embedding_100_hidden_50_lr00004: 0.8560629559423287

# %%
#this test is done with a diffrent input processing : we keep captial letters
model = PoliticalClassifier(f"model_embedding_100_hidden_50_lr00004_capital", embedding_dim=100, hidden_dim=50)
train(model, small_train_dataset, batch_size=128, embedding_dim=100, num_epochs=40,hidden_dim=50, learning_rate=0.00004,small=True, print_stat=True)
# Out:
# Epoch 0 Finished.
# Epoch 1 Finished.
# Epoch 2 Finished.
# Epoch 3 Finished.
# Epoch 4 Finished.
# Epoch 5 Finished.
# Epoch 6 Finished.
# Epoch 7 Finished.
# Epoch 8 Finished.
# Epoch 9 Finished.
# Epoch 10 Finished.
# Epoch 11 Finished.
# Epoch 12 Finished.
# Epoch 13 Finished.
# Epoch 14 Finished.
# Epoch 15 Finished.
# Epoch 16 Finished.
# Epoch 17 Finished.
# Epoch 18 Finished.
# Epoch 19 Finished.
# Epoch 20 Finished.
# Epoch 21 Finished.
# Epoch 22 Finished.
# Epoch 23 Finished.
# Epoch 24 Finished.
# Epoch 25 Finished.
# Epoch 26 Finished.
# Epoch 27 Finished.
# Epoch 28 Finished.
# Epoch 29 Finished.
# Epoch 30 Finished.
# Epoch 31 Finished.
# Epoch 32 Finished.
# Epoch 33 Finished.
# Epoch 34 Finished.
# Epoch 35 Finished.
# Epoch 36 Finished.
# Epoch 37 Finished.
# Epoch 38 Finished.
# Epoch 39 Finished.
# Final Training Accuracy: 0.9032536253084595
# Final Validation Accuracy: 0.8529036705152507
# Final Validation Accuracy model_embedding_100_hidden_50_lr00004_capital: 0.8529036705152507

# %% [markdown]
# ## Final Model

# %%
#final_model only on 16 epochs because the accuracy doesn't really increase past that
model = PoliticalClassifier(f"final_model", embedding_dim=100, hidden_dim=50)
train(model, small_train_dataset, batch_size=128, embedding_dim=100, num_epochs=12,hidden_dim=50, learning_rate=0.00004,small=True, print_stat=True)
# Out:
# Epoch 0 Finished.
# 0.7056184127171691
# Epoch 1 Finished.
# 0.7810699831615019
# Epoch 2 Finished.
# 0.819539222540611
# Epoch 3 Finished.
# 0.839837326322216
# Epoch 4 Finished.
# 0.851617710292491
# Epoch 5 Finished.
# 0.8581299091771456
# Epoch 6 Finished.
# 0.8608805254399181
# Epoch 7 Finished.
# 0.8629221523079903
# Epoch 8 Finished.
# 0.8645469196708451
# Epoch 9 Finished.
# 0.8656924627206155
# Epoch 10 Finished.
# 0.8667493820960483
# Epoch 11 Finished.
# 0.8656333802710572
# Epoch 12 Finished.
# 0.8669889942525906
# Epoch 13 Finished.
# 0.8680984313609642
# Epoch 14 Finished.
# 0.8693687040264689
# Epoch 15 Finished.
# 0.8690995506451475
# Final Training Accuracy: 0.8819511033754452
# Final Validation Accuracy: 0.8690995506451475
# Final Validation Accuracy final_model: 0.8690995506451475

# %% [markdown]
# ## Test

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_path = f"/content/drive/MyDrive/{get_model_name("final_model", batch_size=128, learning_rate=0.00004, hidden_dim = 50, embedding_dim = 100, dropout_prob = 0.5, epoch =7)}"
state = torch.load(model_path, map_location = device) #I took epoch = 7 to avoid overfitting because the validation accuracy doesn't increases a lot past this epoch

final_model = PoliticalClassifier(f"final_model", embedding_dim=100, hidden_dim=50)
final_model.load_state_dict(state)
# Out:
# <All keys matched successfully>

# %%
def get_test_accuracy(model, data):
    if torch.cuda.is_available():
      model.cuda()
    model.eval() #in order not to have dropout
    correct = 0
    total = 0
    with torch.no_grad():
        for text, labels in torch.utils.data.DataLoader(data, batch_size=128):
            #############################################
            # To Enable GPU Usage
            if torch.cuda.is_available():
                text = text.cuda()
                labels = labels.cuda()
            #############################################
            output = model(text)
            #select index with maximum prediction score
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(labels.view_as(pred)).sum().item()
            total += text.shape[0]
    return correct / total

# %%
#test on the test part of the dataset

get_test_accuracy(final_model, test_dataset)
# Out:
# 0.8447633577496546

# %%
pip install ntscraper
# Out:
# Collecting ntscraper
#   Downloading ntscraper-0.4.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.12/dist-packages (from ntscraper) (2.32.4)
# Requirement already satisfied: beautifulsoup4>=4.11 in /usr/local/lib/python3.12/dist-packages (from ntscraper) (4.13.5)
# Requirement already satisfied: lxml>=4.9 in /usr/local/lib/python3.12/dist-packages (from ntscraper) (6.0.2)
# Requirement already satisfied: tqdm>=4.66 in /usr/local/lib/python3.12/dist-packages (from ntscraper) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11->ntscraper) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11->ntscraper) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28->ntscraper) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28->ntscraper) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28->ntscraper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28->ntscraper) (2026.2.25)
# Downloading ntscraper-0.4.0-py3-none-any.whl (12 kB)
# Installing collected packages: ntscraper
# Successfully installed ntscraper-0.4.0

# %%
#test on new data collected directly from X -> the code doesn't work because Nitter is down
#Instead I manually collected the 5 most recent tweets of those 10 accounts
#I got the 20 last tweets from each user among the 5 most active democrat acounts and the 5 most active republicain acounts in my training dataset
from ntscraper import Nitter
import pandas as pd

new_instances = [
    'https://nitter.poast.org',
    'https://nitter.privacy.com.de',
    'https://nitter.projectrenard.im',
    'https://nitter.no-logs.com'
]
scraper = Nitter(instances=new_instances)
def clean_tweet(text):
    """
    Removes URLs from the tweet text (preserves hashtags, mentions, and punctuation.) (the funcion used to clean the previous dataset"""

    # Regex to match http, https, and www links
    url_pattern = r'https?://\S+|www\.\S+'
    text = re.sub(url_pattern, '', text)   #delete urls from the text

    # Strip leading/trailing whitespace
    return text.strip()


def get_tweets_from_user(username, party, limit=50):
    try :
      tweets = scraper.get_tweets(username, mode='user', number=limit)
    except Exception as e:
      print(e)
      return[]
    data = []
    for tweet in tweets['threads']:
        cleaned_text = clean_tweet(tweet['text'])
        if cleaned_text : #ignore tweets that became empty after the cleaning
          data.append({
            'text': cleaned_text,
            'label' : party,
            'time': tweet['date'],
            'user_id': username,

        })
    return data

# Liste des comptes de ton image
dem_accounts = ['RepDonBeyer', 'HispanicCaucus','RepJayapal', 'RepDwightEvans','SenateDems']
rep_accounts = ['auctnr1','chiproytx', 'HouseGOP', 'tedcruz', 'JohnCornyn']

all_recent_tweets = []
for acc in rep_accounts:
    print(f"Collect for {acc}...")
    all_recent_tweets.extend(get_tweets_from_user(acc, 0, limit=20))
for acc in dem_accounts:
    print(f"Collect for {acc}...")
    all_recent_tweets.extend(get_tweets_from_user(acc, 1, limit=20))


new_test_df = pd.DataFrame(all_recent_tweets)
new_test_df.head()
#new_test_df.to_parquet("/content/drive/MyDrive/new_test_dataset.parquet", engine='fastparquet')
# Out:
# Testing instances: 100%|██████████| 4/4 [00:01<00:00,  3.37it/s]
# Collect for auctnr1...
# Cannot choose from an empty sequence
# Collect for chiproytx...
# Cannot choose from an empty sequence
# Collect for HouseGOP...
# Cannot choose from an empty sequence
# Collect for tedcruz...
# Cannot choose from an empty sequence
# Collect for JohnCornyn...
# Cannot choose from an empty sequence
# Collect for RepDonBeyer...
# Cannot choose from an empty sequence
# Collect for HispanicCaucus...
# Cannot choose from an empty sequence
# Collect for RepJayapal...
# Cannot choose from an empty sequence
# Collect for RepDwightEvans...
# Cannot choose from an empty sequence
# Collect for SenateDems...
# Cannot choose from an empty sequence
# Empty DataFrame
# Columns: []
# Index: []

# %%
from math import nan
#instead I just manually retrieved the 5 latest tweets written by each of the 5 most active democrat acounts and the 5 most active republicain acounts in my training dataset
def clean_tweet(text):
    """
    Removes URLs from the tweet text (preserves hashtags, mentions, and punctuation.) (the funcion used to clean the previous dataset"""

    # Regex to match http, https, and www links
    url_pattern = r'https?://\S+|www\.\S+'
    text = re.sub(url_pattern, '', text)   #delete urls from the text

    if text == " "*len(text) or text == nan :
      return ""
    return text.strip()


new_test_df = pd.read_csv('/content/drive/MyDrive/df_test_new.csv', sep=';', encoding='latin1')

new_test_df["text"] = new_test_df["text"].apply(clean_tweet)
new_test_df = new_test_df.dropna(subset=['text']) #if the tweet is empty after the cleaning

new_test_df
# Out:
#                                                  text  label         user_id
# 0   Wishing you all a blessed and joyful Easter Su...      1     RepDonBeyer
# 1   Like everyone else, I had to check that this w...      1     RepDonBeyer
# 2   With the help of federal funding, American sci...      1     RepDonBeyer
# 3   On Good Friday, we look inward to reflect on t...      1     RepDonBeyer
# 4   Praying for the safety of our servicemembers a...      1     RepDonBeyer
# 5   Happy Easter to all who celebrate.\n\nThe @his...      1  HispanicCaucus
# 6   The 14th Amendment is clear. The president can...      1  HispanicCaucus
# 7   Chair @repespaillat\n and the @hispaniccaucus\...      1  HispanicCaucus
# 8   This March 31, we recognize and honor farmwork...      1  HispanicCaucus
# 9   Republicans are holding TSA funds hostage for ...      1  HispanicCaucus
# 10  Thank you to all the Members of Congress who j...      1      RepJayapal
# 11  Happy Easter to all who celebrate! Wishing you...      1      RepJayapal
# 12  Mayor Wilson is making critical new investment...      1      RepJayapal
# 13  Thank you to the incredible witnesses who spok...      1      RepJayapal
# 14  This is great news! It is time that the rich p...      1      RepJayapal
# 15          Hegseth is the one who should be leaving!      1  RepDwightEvans
# 16  Job Fair in #Philly! The Postal Service will h...      1  RepDwightEvans
# 17  Apparently putting our troops and national sec...      1  RepDwightEvans
# 18  Wishing all who will be celebrating in Philade...      1  RepDwightEvans
# 19  I'm proud to stand for the Constitution, which...      1  RepDwightEvans
# 20  Donald Trump wants to pay for his war in Iran ...      1      SenateDems
# 21  According to Donald Trump vote by mail is safe...      1      SenateDems
# 22  ICYMI: Trump said the quiet part out loud. He ...      1      SenateDems
# 23  The Trump administration can?t get its story s...      1      SenateDems
# 24  Watch Senator @ChrisVanHollen\n?s message to S...      1      SenateDems
# 25  US aviator missing after Iran shot down fighte...      0         auctnr1
# 26                              Arizona vs Michigan ?      0         auctnr1
# 27  How many states does Florida lose population t...      0         auctnr1
# 28  I remember well when Swalwell was dating "Chit...      0         auctnr1
# 29  on "the top 3 things you need to know" Nicole ...      0         auctnr1
# 30                   The Master?s Call #HappyEaster -      0       chiproytx
# 31  Why Jesus? Because the tomb is empty. #HappyEa...      0       chiproytx
# 32  Democrats are holding the country hostage and ...      0       chiproytx
# 33  House Republicans should go to Washington this...      0       chiproytx
# 34  Leadership. Remove people who have no allegian...      0       chiproytx
# 35  No words can fully capture the depth of your s...      0        HouseGOP
# 36  When Democrats say they want to Abolish ICE, b...      0        HouseGOP
# 37  ?It?s great for some of us single parents that...      0        HouseGOP
# 38  ?So Joseph bought some linen cloth, took down ...      0        HouseGOP
# 39  ?The curtain of the temple was torn in two fro...      0        HouseGOP
# 40                                        Praise God!      0         tedcruz
# 41                                           all true      0         tedcruz
# 42  This is propaganda?and idiotic. According to t...      0         tedcruz
# 43  The unfortunate consequences for Europe of the...      0         tedcruz
# 44                                        Incredible.      0         tedcruz
# 45  He is risen  ?Christ was raised from the dead...      0      JohnCornyn
# 46  Research shows that the ranks of the affluent ...      0      JohnCornyn
# 47  "In 2024, about 31% of Americans were part of ...      0      JohnCornyn
# 48  With Cheers and Tears, Houston Reclaims Its Pl...      0      JohnCornyn
# 49  Under the Working Families Tax Cut (aka One Bi...      0      JohnCornyn

# %%
X_test_new, y_test_new = new_test_df['text'], new_test_df['label']
print("len of the new test dataset : " +str(len(X_test_new)))

X_test_new_tensor = torch.tensor([encode_text(text) for text in X_test_new], dtype=torch.long)
y_test_new_tensor = torch.tensor(y_test_new, dtype=torch.long)

test_dataset_new = TensorDataset(X_test_new_tensor, y_test_new_tensor)

print("test accuracy on the new dataset "+ str(get_test_accuracy(final_model, test_dataset_new)))
# Out:
# len of the new test dataset : 50
# test accuracy on the new dataset 0.8

# %% [markdown]
# ## Qualitative results

# %%
#Qualitative result for the report, we test the prediction that the model makes for simple poltical or neutral words

test_tweets = ["Trump", "Biden", "I am pro-choice", "I love chocolate", "I don't like Trump", "I like Trump","I don't like Biden", "I like Biden"]

test_df = pd.DataFrame(test_tweets, columns=["tweet"])
test_tweet_encoded = torch.tensor([encode_text(text) for text in test_df["tweet"]], dtype=torch.long)

if torch.cuda.is_available() :
  test_tweet_encoded = test_tweet_encoded.cuda()

final_model.eval()
with torch.no_grad():
    logits = final_model(test_tweet_encoded)
    probability = F.softmax(logits, dim=1).cpu().numpy()

test_df["Proba Rep"] = probability[:, 0]
test_df["Proba Dem"] = probability[:, 1]

test_df["Prediction"]=test_df.apply(lambda row: "Republican" if row["Proba Rep"] > row["Proba Dem"] else "Democrat", axis=1)

display(test_df)
# Out:
#                 tweet  Proba Rep  Proba Dem  Prediction
# 0               Trump   0.149829   0.850171    Democrat
# 1               Biden   0.962260   0.037740  Republican
# 2     I am pro-choice   0.241753   0.758247    Democrat
# 3    I love chocolate   0.535197   0.464803  Republican
# 4  I don't like Trump   0.188355   0.811645    Democrat
# 5        I like Trump   0.204897   0.795103    Democrat
# 6  I don't like Biden   0.925608   0.074392  Republican
# 7        I like Biden   0.944783   0.055217  Republican
